# %%
import pandas as pd

# %%
path = 'data/violence_data.csv'
df = pd.read_csv(path)
df.head(20)
# Out:
#     RecordID      Country Gender Demographics Question  \
# 0          1  Afghanistan      F        Marital status
# 1          1  Afghanistan      F             Education
# 2          1  Afghanistan      F             Education
# 3          1  Afghanistan      F             Education
# 4          1  Afghanistan      F        Marital status
# 5          1  Afghanistan      F            Employment
# 6          1  Afghanistan      F                   Age
# 7          1  Afghanistan      F            Employment
# 8          1  Afghanistan      F             Residence
# 9          1  Afghanistan      F                   Age
# 10         1  Afghanistan      F        Marital status
# 11         1  Afghanistan      F             Residence
# 12         1  Afghanistan      F                   Age
# 13         1  Afghanistan      F             Education
# 14         1  Afghanistan      F            Employment
# 15         1  Afghanistan      M        Marital status
# 16         1  Afghanistan      M             Education
# 17         1  Afghanistan      M             Residence
# 18         1  Afghanistan      M            Employment
# 19         1  Afghanistan      M             Education
#
#            Demographics Response                   Question Survey Year  Value
# 0                  Never married  ... if she burns the food  01/01/2015    NaN
# 1                         Higher  ... if she burns the food  01/01/2015   10.1
# 2                      Secondary  ... if she burns the food  01/01/2015   13.7
# 3                        Primary  ... if she burns the food  01/01/2015   13.8
# 4   Widowed, divorced, separated  ... if she burns the food  01/01/2015   13.8
# 5              Employed for kind  ... if she burns the food  01/01/2015   17.0
# 6                          15-24  ... if she burns the food  01/01/2015   17.3
# 7                     Unemployed  ... if she burns the food  01/01/2015   18.0
# 8                          Rural  ... if she burns the food  01/01/2015   18.1
# 9                          25-34  ... if she burns the food  01/01/2015   18.2
# 10    Married or living together  ... if she burns the food  01/01/2015   18.3
# 11                         Urban  ... if she burns the food  01/01/2015   18.3
# 12                         35-49  ... if she burns the food  01/01/2015   18.8
# 13                  No education  ... if she burns the food  01/01/2015   19.1
# 14             Employed for cash  ... if she burns the food  01/01/2015   20.8
# 15                 Never married  ... if she burns the food  01/01/2015    NaN
# 16                        Higher  ... if she burns the food  01/01/2015    4.5
# 17                         Urban  ... if she burns the food  01/01/2015    4.6
# 18                    Unemployed  ... if she burns the food  01/01/2015    5.2
# 19                       Primary  ... if she burns the food  01/01/2015    6.3

# %%
df['Residence'] = df['Demographics Response'].apply(lambda response: response if response in ['Rural', 'Urban'] else None)
df['Marital status'] = df['Demographics Response'].apply(lambda response: response if response in ['Never married', 'Widowed, divorced, separated'] else None)
df['Education'] = df['Demographics Response'].apply(lambda response: response if response in ['No education','Primary','Secondary','Higher'] else None)
df['Employment'] = df['Demographics Response'].apply(lambda response: response if response in ['Employed for kind', 'Unemployed','Employed for cash'] else None)
df['Age'] = df['Demographics Response'].apply(lambda response: response if response in ['15-24','25-34','35-49'] else None)

# %%
df
# Out:
#        RecordID      Country Gender Demographics Question  \
# 0             1  Afghanistan      F        Marital status
# 1             1  Afghanistan      F             Education
# 2             1  Afghanistan      F             Education
# 3             1  Afghanistan      F             Education
# 4             1  Afghanistan      F        Marital status
# ...         ...          ...    ...                   ...
# 12595       210     Zimbabwe      M             Residence
# 12596       280     Zimbabwe      M             Residence
# 12597       280     Zimbabwe      M             Residence
# 12598       350     Zimbabwe      M             Residence
# 12599       350     Zimbabwe      M             Residence
#
#               Demographics Response                                 Question  \
# 0                     Never married                ... if she burns the food
# 1                            Higher                ... if she burns the food
# 2                         Secondary                ... if she burns the food
# 3                           Primary                ... if she burns the food
# 4      Widowed, divorced, separated                ... if she burns the food
# ...                             ...                                      ...
# 12595                         Urban  ... if she goes out without telling him
# 12596                         Rural         ... if she neglects the children
# 12597                         Urban         ... if she neglects the children
# 12598                         Rural  ... if she refuses to have sex with him
# 12599                         Urban  ... if she refuses to have sex with him
#
#       Survey Year  Value Residence                Marital status  Education  \
# 0      01/01/2015    NaN      None                 Never married       None
# 1      01/01/2015   10.1      None                          None     Higher
# 2      01/01/2015   13.7      None                          None  Secondary
# 3      01/01/2015   13.8      None                          None    Primary
# 4      01/01/2015   13.8      None  Widowed, divorced, separated       None
# ...           ...    ...       ...                           ...        ...
# 12595  01/01/2015   11.8     Urban                          None       None
# 12596  01/01/2015   20.1     Rural                          None       None
# 12597  01/01/2015   15.0     Urban                          None       None
# 12598  01/01/2015    7.2     Rural                          None       None
# 12599  01/01/2015    3.7     Urban                          None       None
#
#       Employment   Age
# 0           None  None
# 1           None  None
# 2           None  None
# 3           None  None
# 4           None  None
# ...          ...   ...
# 12595       None  None
# 12596       None  None
# 12597       None  None
# 12598       None  None
# 12599       None  None
#
# [12600 rows x 13 columns]

# %%
df = df.drop('Demographics Response', axis=1)
df = df.drop('Demographics Question', axis=1)

# %%
df.head(20)
# Out:
#     RecordID      Country Gender                   Question Survey Year  \
# 0          1  Afghanistan      F  ... if she burns the food  01/01/2015
# 1          1  Afghanistan      F  ... if she burns the food  01/01/2015
# 2          1  Afghanistan      F  ... if she burns the food  01/01/2015
# 3          1  Afghanistan      F  ... if she burns the food  01/01/2015
# 4          1  Afghanistan      F  ... if she burns the food  01/01/2015
# 5          1  Afghanistan      F  ... if she burns the food  01/01/2015
# 6          1  Afghanistan      F  ... if she burns the food  01/01/2015
# 7          1  Afghanistan      F  ... if she burns the food  01/01/2015
# 8          1  Afghanistan      F  ... if she burns the food  01/01/2015
# 9          1  Afghanistan      F  ... if she burns the food  01/01/2015
# 10         1  Afghanistan      F  ... if she burns the food  01/01/2015
# 11         1  Afghanistan      F  ... if she burns the food  01/01/2015
# 12         1  Afghanistan      F  ... if she burns the food  01/01/2015
# 13         1  Afghanistan      F  ... if she burns the food  01/01/2015
# 14         1  Afghanistan      F  ... if she burns the food  01/01/2015
# 15         1  Afghanistan      M  ... if she burns the food  01/01/2015
# 16         1  Afghanistan      M  ... if she burns the food  01/01/2015
# 17         1  Afghanistan      M  ... if she burns the food  01/01/2015
# 18         1  Afghanistan      M  ... if she burns the food  01/01/2015
# 19         1  Afghanistan      M  ... if she burns the food  01/01/2015
#
#     Value Residence                Marital status     Education  \
# 0     NaN      None                 Never married          None
# 1    10.1      None                          None        Higher
# 2    13.7      None                          None     Secondary
# 3    13.8      None                          None       Primary
# 4    13.8      None  Widowed, divorced, separated          None
# 5    17.0      None                          None          None
# 6    17.3      None                          None          None
# 7    18.0      None                          None          None
# 8    18.1     Rural                          None          None
# 9    18.2      None                          None          None
# 10   18.3      None                          None          None
# 11   18.3     Urban                          None          None
# 12   18.8      None                          None          None
# 13   19.1      None                          None  No education
# 14   20.8      None                          None          None
# 15    NaN      None                 Never married          None
# 16    4.5      None                          None        Higher
# 17    4.6     Urban                          None          None
# 18    5.2      None                          None          None
# 19    6.3      None                          None       Primary
#
#            Employment    Age
# 0                None   None
# 1                None   None
# 2                None   None
# 3                None   None
# 4                None   None
# 5   Employed for kind   None
# 6                None  15-24
# 7          Unemployed   None
# 8                None   None
# 9                None  25-34
# 10               None   None
# 11               None   None
# 12               None  35-49
# 13               None   None
# 14  Employed for cash   None
# 15               None   None
# 16               None   None
# 17               None   None
# 18         Unemployed   None
# 19               None   None

# %%
desired_order = ['RecordID','Gender','Country','Age','Education','Marital status','Employment','Residence','Survey Year','Question','Value']
df = df[desired_order]

# %%
df
# Out:
#        RecordID Gender      Country   Age  Education  \
# 0             1      F  Afghanistan  None       None
# 1             1      F  Afghanistan  None     Higher
# 2             1      F  Afghanistan  None  Secondary
# 3             1      F  Afghanistan  None    Primary
# 4             1      F  Afghanistan  None       None
# ...         ...    ...          ...   ...        ...
# 12595       210      M     Zimbabwe  None       None
# 12596       280      M     Zimbabwe  None       None
# 12597       280      M     Zimbabwe  None       None
# 12598       350      M     Zimbabwe  None       None
# 12599       350      M     Zimbabwe  None       None
#
#                      Marital status Employment Residence Survey Year  \
# 0                     Never married       None      None  01/01/2015
# 1                              None       None      None  01/01/2015
# 2                              None       None      None  01/01/2015
# 3                              None       None      None  01/01/2015
# 4      Widowed, divorced, separated       None      None  01/01/2015
# ...                             ...        ...       ...         ...
# 12595                          None       None     Urban  01/01/2015
# 12596                          None       None     Rural  01/01/2015
# 12597                          None       None     Urban  01/01/2015
# 12598                          None       None     Rural  01/01/2015
# 12599                          None       None     Urban  01/01/2015
#
#                                       Question  Value
# 0                    ... if she burns the food    NaN
# 1                    ... if she burns the food   10.1
# 2                    ... if she burns the food   13.7
# 3                    ... if she burns the food   13.8
# 4                    ... if she burns the food   13.8
# ...                                        ...    ...
# 12595  ... if she goes out without telling him   11.8
# 12596         ... if she neglects the children   20.1
# 12597         ... if she neglects the children   15.0
# 12598  ... if she refuses to have sex with him    7.2
# 12599  ... if she refuses to have sex with him    3.7
#
# [12600 rows x 11 columns]

# %%
import pandas as pd
from itertools import product

def generate_combinations(group):

    unique_values = {col: group[col].unique() for col in group.columns[3:10]}
    combinations = list(product(*unique_values.values()))

    result = pd.DataFrame(combinations, columns=unique_values.keys())

    result[group.columns[:3]] = group[group.columns[:3]].iloc[0]

    return result

result_df = df.groupby(['Country']).apply(generate_combinations).reset_index(drop=True)


result_df = result_df.dropna()

result_df
# Out:
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# ...
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
# C:\Users\ASUS I5\AppData\Local\Temp\ipykernel_22172\3801828469.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result[group.columns[:3]] = group[group.columns[:3]].iloc[0]
#           Age  Education                Marital status         Employment  \
# 1320    15-24     Higher                 Never married  Employed for kind
# 1321    15-24     Higher                 Never married  Employed for kind
# 1322    15-24     Higher                 Never married  Employed for kind
# 1323    15-24     Higher                 Never married  Employed for kind
# 1324    15-24     Higher                 Never married  Employed for kind
# ...       ...        ...                           ...                ...
# 301315  35-49  Secondary  Widowed, divorced, separated         Unemployed
# 301316  35-49  Secondary  Widowed, divorced, separated         Unemployed
# 301317  35-49  Secondary  Widowed, divorced, separated         Unemployed
# 301318  35-49  Secondary  Widowed, divorced, separated         Unemployed
# 301319  35-49  Secondary  Widowed, divorced, separated         Unemployed
#
#        Residence Survey Year                                 Question  \
# 1320       Rural  01/01/2015                ... if she burns the food
# 1321       Rural  01/01/2015     ... for at least one specific reason
# 1322       Rural  01/01/2015               ... if she argues with him
# 1323       Rural  01/01/2015  ... if she goes out without telling him
# 1324       Rural  01/01/2015         ... if she neglects the children
# ...          ...         ...                                      ...
# 301315     Urban  01/01/2015               ... if she argues with him
# 301316     Urban  01/01/2015                ... if she burns the food
# 301317     Urban  01/01/2015  ... if she goes out without telling him
# 301318     Urban  01/01/2015         ... if she neglects the children
# 301319     Urban  01/01/2015  ... if she refuses to have sex with him
#
#         RecordID Gender      Country
# 1320           1      F  Afghanistan
# 1321           1      F  Afghanistan
# 1322           1      F  Afghanistan
# 1323           1      F  Afghanistan
# 1324           1      F  Afghanistan
# ...          ...    ...          ...
# 301315       420      F     Zimbabwe
# 301316       420      F     Zimbabwe
# 301317       420      F     Zimbabwe
# 301318       420      F     Zimbabwe
# 301319       420      F     Zimbabwe
#
# [60480 rows x 10 columns]

# %%
order_df = ['RecordID','Gender','Country','Age','Education','Marital status','Employment','Residence','Survey Year','Question']
result_df = result_df[order_df]

# %%
result_df
# Out:
#         RecordID Gender      Country    Age  Education  \
# 1320           1      F  Afghanistan  15-24     Higher
# 1321           1      F  Afghanistan  15-24     Higher
# 1322           1      F  Afghanistan  15-24     Higher
# 1323           1      F  Afghanistan  15-24     Higher
# 1324           1      F  Afghanistan  15-24     Higher
# ...          ...    ...          ...    ...        ...
# 301315       420      F     Zimbabwe  35-49  Secondary
# 301316       420      F     Zimbabwe  35-49  Secondary
# 301317       420      F     Zimbabwe  35-49  Secondary
# 301318       420      F     Zimbabwe  35-49  Secondary
# 301319       420      F     Zimbabwe  35-49  Secondary
#
#                       Marital status         Employment Residence Survey Year  \
# 1320                   Never married  Employed for kind     Rural  01/01/2015
# 1321                   Never married  Employed for kind     Rural  01/01/2015
# 1322                   Never married  Employed for kind     Rural  01/01/2015
# 1323                   Never married  Employed for kind     Rural  01/01/2015
# 1324                   Never married  Employed for kind     Rural  01/01/2015
# ...                              ...                ...       ...         ...
# 301315  Widowed, divorced, separated         Unemployed     Urban  01/01/2015
# 301316  Widowed, divorced, separated         Unemployed     Urban  01/01/2015
# 301317  Widowed, divorced, separated         Unemployed     Urban  01/01/2015
# 301318  Widowed, divorced, separated         Unemployed     Urban  01/01/2015
# 301319  Widowed, divorced, separated         Unemployed     Urban  01/01/2015
#
#                                        Question
# 1320                  ... if she burns the food
# 1321       ... for at least one specific reason
# 1322                 ... if she argues with him
# 1323    ... if she goes out without telling him
# 1324           ... if she neglects the children
# ...                                         ...
# 301315               ... if she argues with him
# 301316                ... if she burns the food
# 301317  ... if she goes out without telling him
# 301318         ... if she neglects the children
# 301319  ... if she refuses to have sex with him
#
# [60480 rows x 10 columns]

# %%
result_df['Survey Year'] = pd.to_datetime(result_df['Survey Year'])

# %%
result_df['Survey Year'] = result_df['Survey Year'].dt.year

# %%
result_df
# Out:
#         RecordID Gender      Country    Age  Education  \
# 1320           1      F  Afghanistan  15-24     Higher
# 1321           1      F  Afghanistan  15-24     Higher
# 1322           1      F  Afghanistan  15-24     Higher
# 1323           1      F  Afghanistan  15-24     Higher
# 1324           1      F  Afghanistan  15-24     Higher
# ...          ...    ...          ...    ...        ...
# 301315       420      F     Zimbabwe  35-49  Secondary
# 301316       420      F     Zimbabwe  35-49  Secondary
# 301317       420      F     Zimbabwe  35-49  Secondary
# 301318       420      F     Zimbabwe  35-49  Secondary
# 301319       420      F     Zimbabwe  35-49  Secondary
#
#                       Marital status         Employment Residence  \
# 1320                   Never married  Employed for kind     Rural
# 1321                   Never married  Employed for kind     Rural
# 1322                   Never married  Employed for kind     Rural
# 1323                   Never married  Employed for kind     Rural
# 1324                   Never married  Employed for kind     Rural
# ...                              ...                ...       ...
# 301315  Widowed, divorced, separated         Unemployed     Urban
# 301316  Widowed, divorced, separated         Unemployed     Urban
# 301317  Widowed, divorced, separated         Unemployed     Urban
# 301318  Widowed, divorced, separated         Unemployed     Urban
# 301319  Widowed, divorced, separated         Unemployed     Urban
#
#         Survey Year                                 Question
# 1320           2015                ... if she burns the food
# 1321           2015     ... for at least one specific reason
# 1322           2015               ... if she argues with him
# 1323           2015  ... if she goes out without telling him
# 1324           2015         ... if she neglects the children
# ...             ...                                      ...
# 301315         2015               ... if she argues with him
# 301316         2015                ... if she burns the food
# 301317         2015  ... if she goes out without telling him
# 301318         2015         ... if she neglects the children
# 301319         2015  ... if she refuses to have sex with him
#
# [60480 rows x 10 columns]

# %%
result_df = result_df.reset_index(drop=True)
result_df
# Out:
#        RecordID Gender      Country    Age  Education  \
# 0             1      F  Afghanistan  15-24     Higher
# 1             1      F  Afghanistan  15-24     Higher
# 2             1      F  Afghanistan  15-24     Higher
# 3             1      F  Afghanistan  15-24     Higher
# 4             1      F  Afghanistan  15-24     Higher
# ...         ...    ...          ...    ...        ...
# 60475       420      F     Zimbabwe  35-49  Secondary
# 60476       420      F     Zimbabwe  35-49  Secondary
# 60477       420      F     Zimbabwe  35-49  Secondary
# 60478       420      F     Zimbabwe  35-49  Secondary
# 60479       420      F     Zimbabwe  35-49  Secondary
#
#                      Marital status         Employment Residence  Survey Year  \
# 0                     Never married  Employed for kind     Rural         2015
# 1                     Never married  Employed for kind     Rural         2015
# 2                     Never married  Employed for kind     Rural         2015
# 3                     Never married  Employed for kind     Rural         2015
# 4                     Never married  Employed for kind     Rural         2015
# ...                             ...                ...       ...          ...
# 60475  Widowed, divorced, separated         Unemployed     Urban         2015
# 60476  Widowed, divorced, separated         Unemployed     Urban         2015
# 60477  Widowed, divorced, separated         Unemployed     Urban         2015
# 60478  Widowed, divorced, separated         Unemployed     Urban         2015
# 60479  Widowed, divorced, separated         Unemployed     Urban         2015
#
#                                       Question
# 0                    ... if she burns the food
# 1         ... for at least one specific reason
# 2                   ... if she argues with him
# 3      ... if she goes out without telling him
# 4             ... if she neglects the children
# ...                                        ...
# 60475               ... if she argues with him
# 60476                ... if she burns the food
# 60477  ... if she goes out without telling him
# 60478         ... if she neglects the children
# 60479  ... if she refuses to have sex with him
#
# [60480 rows x 10 columns]

# %%
albania_data = result_df[(result_df['Country'] == 'Albania') & (result_df['Employment'] == 'Employed for cash')]
albania_data
# Out:
#       RecordID Gender  Country    Age     Education  \
# 864          2      F  Albania  15-24        Higher
# 865          2      F  Albania  15-24        Higher
# 866          2      F  Albania  15-24        Higher
# 867          2      F  Albania  15-24        Higher
# 868          2      F  Albania  15-24        Higher
# ...        ...    ...      ...    ...           ...
# 1699         2      F  Albania  35-49  No education
# 1700         2      F  Albania  35-49  No education
# 1701         2      F  Albania  35-49  No education
# 1702         2      F  Albania  35-49  No education
# 1703         2      F  Albania  35-49  No education
#
#                     Marital status         Employment Residence  Survey Year  \
# 864                  Never married  Employed for cash     Urban         2017
# 865                  Never married  Employed for cash     Urban         2017
# 866                  Never married  Employed for cash     Urban         2017
# 867                  Never married  Employed for cash     Urban         2017
# 868                  Never married  Employed for cash     Urban         2017
# ...                            ...                ...       ...          ...
# 1699  Widowed, divorced, separated  Employed for cash     Rural         2017
# 1700  Widowed, divorced, separated  Employed for cash     Rural         2017
# 1701  Widowed, divorced, separated  Employed for cash     Rural         2017
# 1702  Widowed, divorced, separated  Employed for cash     Rural         2017
# 1703  Widowed, divorced, separated  Employed for cash     Rural         2017
#
#                                      Question
# 864                 ... if she burns the food
# 865      ... for at least one specific reason
# 866                ... if she argues with him
# 867   ... if she goes out without telling him
# 868          ... if she neglects the children
# ...                                       ...
# 1699     ... for at least one specific reason
# 1700               ... if she argues with him
# 1701  ... if she goes out without telling him
# 1702         ... if she neglects the children
# 1703  ... if she refuses to have sex with him
#
# [288 rows x 10 columns]

# %%
result_df.drop('RecordID', axis=1, inplace=True)
result_df
# Out:
#       Gender      Country    Age  Education                Marital status  \
# 0          F  Afghanistan  15-24     Higher                 Never married
# 1          F  Afghanistan  15-24     Higher                 Never married
# 2          F  Afghanistan  15-24     Higher                 Never married
# 3          F  Afghanistan  15-24     Higher                 Never married
# 4          F  Afghanistan  15-24     Higher                 Never married
# ...      ...          ...    ...        ...                           ...
# 60475      F     Zimbabwe  35-49  Secondary  Widowed, divorced, separated
# 60476      F     Zimbabwe  35-49  Secondary  Widowed, divorced, separated
# 60477      F     Zimbabwe  35-49  Secondary  Widowed, divorced, separated
# 60478      F     Zimbabwe  35-49  Secondary  Widowed, divorced, separated
# 60479      F     Zimbabwe  35-49  Secondary  Widowed, divorced, separated
#
#               Employment Residence  Survey Year  \
# 0      Employed for kind     Rural         2015
# 1      Employed for kind     Rural         2015
# 2      Employed for kind     Rural         2015
# 3      Employed for kind     Rural         2015
# 4      Employed for kind     Rural         2015
# ...                  ...       ...          ...
# 60475         Unemployed     Urban         2015
# 60476         Unemployed     Urban         2015
# 60477         Unemployed     Urban         2015
# 60478         Unemployed     Urban         2015
# 60479         Unemployed     Urban         2015
#
#                                       Question
# 0                    ... if she burns the food
# 1         ... for at least one specific reason
# 2                   ... if she argues with him
# 3      ... if she goes out without telling him
# 4             ... if she neglects the children
# ...                                        ...
# 60475               ... if she argues with him
# 60476                ... if she burns the food
# 60477  ... if she goes out without telling him
# 60478         ... if she neglects the children
# 60479  ... if she refuses to have sex with him
#
# [60480 rows x 9 columns]

# %%
order_df = ['Country','Age','Education','Marital status','Employment','Residence','Question']
result_df = result_df[order_df]
result_df
# Out:
#            Country    Age  Education                Marital status  \
# 0      Afghanistan  15-24     Higher                 Never married
# 1      Afghanistan  15-24     Higher                 Never married
# 2      Afghanistan  15-24     Higher                 Never married
# 3      Afghanistan  15-24     Higher                 Never married
# 4      Afghanistan  15-24     Higher                 Never married
# ...            ...    ...        ...                           ...
# 60475     Zimbabwe  35-49  Secondary  Widowed, divorced, separated
# 60476     Zimbabwe  35-49  Secondary  Widowed, divorced, separated
# 60477     Zimbabwe  35-49  Secondary  Widowed, divorced, separated
# 60478     Zimbabwe  35-49  Secondary  Widowed, divorced, separated
# 60479     Zimbabwe  35-49  Secondary  Widowed, divorced, separated
#
#               Employment Residence                                 Question
# 0      Employed for kind     Rural                ... if she burns the food
# 1      Employed for kind     Rural     ... for at least one specific reason
# 2      Employed for kind     Rural               ... if she argues with him
# 3      Employed for kind     Rural  ... if she goes out without telling him
# 4      Employed for kind     Rural         ... if she neglects the children
# ...                  ...       ...                                      ...
# 60475         Unemployed     Urban               ... if she argues with him
# 60476         Unemployed     Urban                ... if she burns the food
# 60477         Unemployed     Urban  ... if she goes out without telling him
# 60478         Unemployed     Urban         ... if she neglects the children
# 60479         Unemployed     Urban  ... if she refuses to have sex with him
#
# [60480 rows x 7 columns]

# %%
import numpy as np
from mlxtend.frequent_patterns import apriori, association_rules

# %%
result_df.Country.unique()
# Out:
# array(['Afghanistan', 'Albania', 'Angola', 'Armenia', 'Azerbaijan',
#        'Bangladesh', 'Benin', 'Bolivia', 'Burkina Faso', 'Burundi',
#        'Cambodia', 'Cameroon', 'Chad', 'Colombia', 'Comoros', 'Congo',
#        'Congo Democratic Republic', "Cote d'Ivoire", 'Dominican Republic',
#        'Egypt', 'Eritrea', 'Eswatini', 'Ethiopia', 'Gabon', 'Gambia',
#        'Ghana', 'Guatemala', 'Guinea', 'Guyana', 'Haiti', 'Honduras',
#        'India', 'Indonesia', 'Jordan', 'Kenya', 'Kyrgyz Republic',
#        'Lesotho', 'Liberia', 'Madagascar', 'Malawi', 'Maldives', 'Mali',
#        'Moldova', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nepal',
#        'Nicaragua', 'Niger', 'Nigeria', 'Pakistan', 'Peru', 'Philippines',
#        'Rwanda', 'Sao Tome and Principe', 'Senegal', 'Sierra Leone',
#        'South Africa', 'Tajikistan', 'Tanzania', 'Timor-Leste', 'Togo',
#        'Turkey', 'Turkmenistan', 'Uganda', 'Ukraine', 'Yemen', 'Zambia',
#        'Zimbabwe'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori

# %%
result_df
# Out:
#            Country    Age  Education                Marital status  \
# 0      Afghanistan  15-24     Higher                 Never married
# 1      Afghanistan  15-24     Higher                 Never married
# 2      Afghanistan  15-24     Higher                 Never married
# 3      Afghanistan  15-24     Higher                 Never married
# 4      Afghanistan  15-24     Higher                 Never married
# ...            ...    ...        ...                           ...
# 60475     Zimbabwe  35-49  Secondary  Widowed, divorced, separated
# 60476     Zimbabwe  35-49  Secondary  Widowed, divorced, separated
# 60477     Zimbabwe  35-49  Secondary  Widowed, divorced, separated
# 60478     Zimbabwe  35-49  Secondary  Widowed, divorced, separated
# 60479     Zimbabwe  35-49  Secondary  Widowed, divorced, separated
#
#               Employment Residence                                 Question
# 0      Employed for kind     Rural                ... if she burns the food
# 1      Employed for kind     Rural     ... for at least one specific reason
# 2      Employed for kind     Rural               ... if she argues with him
# 3      Employed for kind     Rural  ... if she goes out without telling him
# 4      Employed for kind     Rural         ... if she neglects the children
# ...                  ...       ...                                      ...
# 60475         Unemployed     Urban               ... if she argues with him
# 60476         Unemployed     Urban                ... if she burns the food
# 60477         Unemployed     Urban  ... if she goes out without telling him
# 60478         Unemployed     Urban         ... if she neglects the children
# 60479         Unemployed     Urban  ... if she refuses to have sex with him
#
# [60480 rows x 7 columns]

# %%
result_df = result_df.astype(str)
df = result_df

# %%
#Grouped by countries


def get_frequent_itemsets_by_country(df, country_name, min_support=0.01,min_length=3):
  country_transactions = df[df['Country'] == country_name].values.tolist()

  te = TransactionEncoder()
  te_ary = te.fit(country_transactions).transform(country_transactions)
  df_encoded = pd.DataFrame(te_ary, columns=te.columns_)

  frequent_itemset = apriori(df_encoded, min_support=min_support,min_length=min_length ,use_colnames=True)
  frequent_itemset = frequent_itemset.sort_values(by="support", ascending=False)
  frequent_itemset['length'] = frequent_itemset['itemsets'].apply(lambda x:len(x))

  result_df = frequent_itemset[(frequent_itemset['length'] >= min_length) & (frequent_itemset['support'] >= min_support)]

  return result_df

# %%
country_name = 'Albania'
result_for_country = get_frequent_itemsets_by_country(df, country_name)
result_for_country
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 2
#       1 country_name = 'Albania'
# ----> 2 result_for_country = get_frequent_itemsets_by_country(df, country_name)
#       3 result_for_country
#
# Cell In[71], line 11, in get_frequent_itemsets_by_country(df, country_name, min_support, min_length)
#       8 te_ary = te.fit(country_transactions).transform(country_transactions)
#       9 df_encoded = pd.DataFrame(te_ary, columns=te.columns_)
# ---> 11 frequent_itemset = apriori(df_encoded, min_support=min_support,min_length=min_length ,use_colnames=True)
#      12 frequent_itemset = frequent_itemset.sort_values(by="support", ascending=False)
#      13 frequent_itemset['length'] = frequent_itemset['itemsets'].apply(lambda x:len(x))
#
# TypeError: apriori() got an unexpected keyword argument 'min_length'

# %%
import pickle 
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier()

# %%
pickle.dump(model, open('model.pkl', 'wb'))

# %%
pickled_model = pickle.load(open('model.pkl', 'rb'))
pickled_model

# %%
# !git config --global user.email "yl.boudchicha@esi-sba.dz"
# !git config --global user.name "Leyna911"
# !git config --global user.password "Sunflower2001#"

# %%
# !git init

# %%
# !git add .

# %%
# !git commit -m "Apriori algorithm "

# %%
# !git remote add origin https://github.com/Leyna911/Violence_against_Women_and_Girls_Mini_Projet.git

# %%
# !git push -u origin master
